# %%
from sklearn.linear_model import LinearRegression

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error  #error checking system

from sklearn.datasets import load_boston

# %%
ds=load_boston()

# %%
ds
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
ds.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
ds.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
ds.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
ds.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
ds.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
df=pd.DataFrame(data=ds.data,columns=ds.feature_names)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df['target']=pd.DataFrame(data=ds.target)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos=df
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
bos.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# target     float64
# dtype: object

# %%
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
sns.heatmap(bos.isnull())
# Out:
# <AxesSubplot:>

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# target     1.108098
# dtype: float64

# %%
bos['CRIM'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos['ZN'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos.plot(kind='box',subplots=True,layout=(3,5))
# Out:
# CRIM          AxesSubplot(0.125,0.657941;0.133621x0.222059)
# ZN         AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# INDUS       AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# CHAS       AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# NOX        AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# RM            AxesSubplot(0.125,0.391471;0.133621x0.222059)
# AGE        AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# DIS         AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# RAD        AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# TAX        AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# PTRATIO          AxesSubplot(0.125,0.125;0.133621x0.222059)
# B             AxesSubplot(0.285345,0.125;0.133621x0.222059)
# LSTAT          AxesSubplot(0.44569,0.125;0.133621x0.222059)
# target        AxesSubplot(0.606034,0.125;0.133621x0.222059)
# dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(bos))
z
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT    target
# ...

# %%
bos['CRIM'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(np.where(z>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
z[55:0]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, target]
# Index: []

# %%
z.iloc[55][1]
# Out:
# 3.375038763517294

# %%
bos['CRIM']=np.log(bos['CRIM'])    # Removes the skeness

# %%
from scipy.stats import boxcox
bos['CRIM']=boxcox(abs(bos['CRIM']),0.5)

# %%
bos['CRIM'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
bos.skew()   #Skey newss of CRIM is removed
# Out:
# CRIM      -0.712790
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# target     1.108098
# dtype: float64

# %%
bos['CRIM']
# Out:
# 0      2.500683
# 1      1.794998
# 2      1.795384
# 3      1.704334
# 4      1.269816
#          ...
# 501    1.328970
# 502    1.518585
# 503    1.347132
# 504    0.973892
# 505    1.492233
# Name: CRIM, Length: 506, dtype: float64

# %%
plt.scatter(bos['B'],bos['target'])

# %%
plt.scatter(bos['CRIM'],bos['target'])

# %%
x=bos['RM']
y=bos['target']
plt.scatter(x,y)
plt.show()

# %%
sns.pairplot(bos)

# %%
corr_hmap=bos.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,cmap='Blues',annot=True)
plt.show()

# %%
plt.scatter(bos['target'],bos['LSTAT'])

# %%
bos.drop('LSTAT',axis=1,inplace=True)  #LSTAT is removed as it was very negative

# %%
bos
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    2.500683  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    1.794998   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    1.795384   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    1.704334   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    1.269816   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  1.328970   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  1.518585   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  1.347132   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.973892   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  1.492233   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
bos_new=bos[(z<3).all(axis=1)]  #Removing outliers

# %%
bos_new
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    2.500683  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    1.794998   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    1.795384   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    1.704334   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    1.269816   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  1.328970   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  1.518585   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  1.347132   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.973892   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  1.492233   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos_new.shape
# Out:
# (415, 13)

# %%
x=df.iloc[:,0:12]
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    2.500683  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    1.794998   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    1.795384   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    1.704334   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    1.269816   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  1.328970   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  1.518585   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  1.347132   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.973892   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  1.492233   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
x=df.iloc[:,0:-1]
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    2.500683  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    1.794998   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    1.795384   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    1.704334   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    1.269816   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  1.328970   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  1.518585   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  1.347132   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.973892   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  1.492233   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, Length: 506, dtype: float64

# %%
x.shape
# Out:
# (506, 12)

# %%
y.shape
# Out:
# (506,)

# %%
x=bos_new.iloc[:,0:12]
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    2.500683  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    1.794998   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    1.795384   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    1.704334   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    1.269816   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  1.328970   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  1.518585   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  1.347132   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.973892   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  1.492233   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
y=bos_new.iloc[:,-1]    #taking last column only
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, Length: 415, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (278, 12)

# %%
y_train.shape
# Out:
# (278,)

# %%
x_test.shape
# Out:
# (137, 12)

# %%
y_test.shape
# Out:
# (137,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-1.06299132e+00, -2.82803578e-03, -4.56377147e-02,  1.58147800e-13,
#        -1.36710722e+01,  8.15172684e+00, -7.03751017e-02, -1.18973135e+00,
#         1.48971611e-01, -1.13828859e-02, -8.00431210e-01,  8.31062879e-03])

# %%
lm.intercept_
# Out:
# 4.006880407048271

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'target'],
#       dtype='object')

# %%
lm.score(x_train,y_train)
# Out:
# 0.7504556112605238

# %%
pred=lm.predict(x_test)

# %%
print("Predicted values are = ",pred)
# Out:
# Predicted values are =  [20.90668296 14.30289896 31.69150643 18.66709891 12.68284153 20.42707927
#  16.59515879 24.35205048 30.00448848 10.70335614 18.36119476 14.3531669
#   9.78080448 23.97850454 27.76006375 10.03322339 25.50225861 27.25136195
#  24.42137718 14.33310813 22.14185373 19.05183898 23.46146858 11.93217877
#  21.83017713 21.82411391 32.6069194  27.10102584 21.62537768 25.38842556
#  32.64253345 15.85883362 13.74537727 26.34788735 15.65526144 16.1628026
#  26.99292263 22.02547532 13.48890732 18.80295723 16.56712381 18.76375105
#  19.90625268 25.81198647 18.02117512 26.49589925 20.10745044 19.49387996
#  17.79965179 23.63883336 20.71463694 19.55353556 39.14312979 14.64474618
#  18.9115223  21.66699448 18.72025768 41.53179616 19.31481953 18.44921095
#  26.3901656  18.21900458 24.31809325 27.92646545 13.23367039  4.20021198
#  34.23629446 20.04189381 19.90820332 22.46575164 35.96276791 19.32645845
#  23.8887744  24.32105955 15.72139569 22.55948067 17.2703363  18.87799646
# ...

# %%
print("Actual Values are = ",y_test)
# Out:
# Actual Values are =  58     23.3
# 146    15.6
# 187    32.0
# 59     19.6
# 407    27.9
#        ...
# 287    23.2
# 488    15.2
# 318    23.1
# 113    18.7
# 184    26.4
# Name: target, Length: 137, dtype: float64

# %%
print("Error :")

print("Mean Absolute Error = ",mean_absolute_error(y_test,pred))
print("mean squared error = ",mean_squared_error(y_test,pred))

print("root mean squared error = ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error :
# Mean Absolute Error =  2.8163563548708916
# mean squared error =  24.75912155313681
# root mean squared error =  4.975853851665743

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))          

#coefficient of determination) regression 
#score function. Best possible score is 1.0 and 
#it can be negative (because the model can be arbitrarily worse).
# Out:
# 0.5718043353646871

# %%
t=np.array([4,5,6,7,8,9,11,1,2,14,15,16])

# %%
t.shape
# Out:
# (12,)

# %%
t=t.reshape(1,-1)

# %%
t.shape
# Out:
# (1, 12)

# %%
lm.predict(t)
# Out:
# array([-50.23485976])

# %%
df=pd.DataFrame(pred)
df.to_csv('house_price_prediction.csv')
