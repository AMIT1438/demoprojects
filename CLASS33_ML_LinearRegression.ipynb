# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('empl.csv')

# %%
ds
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df=pd.DataFrame(data=ds)

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df.describe()
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
df.dtypes
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %%
df1=df.drop(['Name'],axis=1)
#df1=df.drop(['Name'],axis=1,inplace=True)     #original df will get affected and Name will be deleted

# %%
df1
# Out:
#     SNo   Age       City  Country   Salary
# 0     1  28.0    Toronto   Canada  20000.0
# 1     2  31.0    Edmonto   Canada   3900.0
# 2     3  34.0    Toronto   Canada   8000.0
# 3     4  26.0   HongKong     Asia  66672.0
# 4     5  30.0        NaN  America      NaN
# 5     6   NaN   HongKong     Asia  30007.0
# 6     7  43.0    BayArea  America   8300.0
# 7     8  38.0  Hyderabad     Asia  54666.0
# 8     9  50.0    newyork  America  67666.0
# 9    11   NaN    newyork  America   8888.0
# 10   12  26.0   HongKong     Asia  66672.0
# 11   13  30.0        NaN  America  34344.0
# 12   14  22.0   HongKong     Asia  30007.0
# 13   15  43.0        NaN  America   8300.0
# 14   16  38.0  Hyderabad     Asia  54666.0
# 15   17   NaN    newyork  America  67666.0
# 16   18  27.0    newyork  America   8888.0
# 17   19  31.0    Edmonto   Canada      NaN
# 18   20  34.0      Congo   Africa  34432.0
# 19   21  32.0     Angola   Africa  34534.0
# 20   22  26.0    Finland   Europe  33451.0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
ds['Age']=ds['Age'].fillna((ds['Age'].median()))

# %%
df.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
ds
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet  31.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  31.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  31.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
import numpy as np
ds=ds.replace(np.NaN,ds['Salary'].mean()) #ds=ds.replace(-1,ds['Salary'].mean())

# %%
ds
# Out:
#     SNo    Name   Age          City  Country        Salary
# 0     1     Tom  28.0       Toronto   Canada  20000.000000
# 1     2     Lee  31.0       Edmonto   Canada   3900.000000
# 2     3    Dave  34.0       Toronto   Canada   8000.000000
# 3     4    Anik  26.0      HongKong     Asia  66672.000000
# 4     5   kamal  30.0  33739.947368  America  33739.947368
# 5     6    Geet  31.0      HongKong     Asia  30007.000000
# 6     7  Steven  43.0       BayArea  America   8300.000000
# 7     8     Ram  38.0     Hyderabad     Asia  54666.000000
# 8     9    hari  50.0       newyork  America  67666.000000
# 9    11    yami  31.0       newyork  America   8888.000000
# 10   12    Anik  26.0      HongKong     Asia  66672.000000
# 11   13   kamal  30.0  33739.947368  America  34344.000000
# 12   14    Geet  22.0      HongKong     Asia  30007.000000
# 13   15  Steven  43.0  33739.947368  America   8300.000000
# 14   16     Ram  38.0     Hyderabad     Asia  54666.000000
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan, strategy='mean')

df['Age']=imp.fit_transform(df['Age'].values.reshape(-1,1))
df['Salary']=imp.fit_transform(df['Salary'].values.reshape(-1,1))

# %%
df
# Out:
#     SNo    Name   Age       City  Country        Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.000000
# 1     2     Lee  31.0    Edmonto   Canada   3900.000000
# 2     3    Dave  34.0    Toronto   Canada   8000.000000
# 3     4    Anik  26.0   HongKong     Asia  66672.000000
# 4     5   kamal  30.0        NaN  America  33739.947368
# 5     6    Geet  31.0   HongKong     Asia  30007.000000
# 6     7  Steven  43.0    BayArea  America   8300.000000
# 7     8     Ram  38.0  Hyderabad     Asia  54666.000000
# 8     9    hari  50.0    newyork  America  67666.000000
# 9    11    yami  31.0    newyork  America   8888.000000
# 10   12    Anik  26.0   HongKong     Asia  66672.000000
# 11   13   kamal  30.0        NaN  America  34344.000000
# 12   14    Geet  22.0   HongKong     Asia  30007.000000
# 13   15  Steven  43.0        NaN  America   8300.000000
# 14   16     Ram  38.0  Hyderabad     Asia  54666.000000
# 15   17    hari  31.0    newyork  America  67666.000000
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='most_frequent')

df['City']=imp.fit_transform(df['City'].values.reshape(-1,1))

# %%
df
# Out:
#     SNo    Name   Age       City  Country        Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.000000
# 1     2     Lee  31.0    Edmonto   Canada   3900.000000
# 2     3    Dave  34.0    Toronto   Canada   8000.000000
# 3     4    Anik  26.0   HongKong     Asia  66672.000000
# 4     5   kamal  30.0   HongKong  America  33739.947368
# 5     6    Geet  31.0   HongKong     Asia  30007.000000
# 6     7  Steven  43.0    BayArea  America   8300.000000
# 7     8     Ram  38.0  Hyderabad     Asia  54666.000000
# 8     9    hari  50.0    newyork  America  67666.000000
# 9    11    yami  31.0    newyork  America   8888.000000
# 10   12    Anik  26.0   HongKong     Asia  66672.000000
# 11   13   kamal  30.0   HongKong  America  34344.000000
# 12   14    Geet  22.0   HongKong     Asia  30007.000000
# 13   15  Steven  43.0   HongKong  America   8300.000000
# 14   16     Ram  38.0  Hyderabad     Asia  54666.000000
# 15   17    hari  31.0    newyork  America  67666.000000
# ...

# %%
le=LabelEncoder()
#df['City']=le.fit_transform(df['City'])

list1=['City','Country']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))  #astype(str) is given to treat the column value as string by force
    
df
# Out:
#     SNo    Name   Age  City  Country        Salary
# 0     1     Tom  28.0     8        3  20000.000000
# 1     2     Lee  31.0     3        3   3900.000000
# 2     3    Dave  34.0     8        3   8000.000000
# 3     4    Anik  26.0     5        2  66672.000000
# 4     5   kamal  30.0     5        1  33739.947368
# 5     6    Geet  31.0     5        2  30007.000000
# 6     7  Steven  43.0     1        1   8300.000000
# 7     8     Ram  38.0     6        2  54666.000000
# 8     9    hari  50.0     9        1  67666.000000
# 9    11    yami  31.0     9        1   8888.000000
# 10   12    Anik  26.0     5        2  66672.000000
# 11   13   kamal  30.0     5        1  34344.000000
# 12   14    Geet  22.0     5        2  30007.000000
# 13   15  Steven  43.0     5        1   8300.000000
# 14   16     Ram  38.0     6        2  54666.000000
# 15   17    hari  31.0     9        1  67666.000000
# 16   18    yami  27.0     9        1   8888.000000
# ...

# %%
ds=pd.read_csv('age_salary.csv')

# %%
ds
# Out:
#    index   Nation purchased_item   salary   age
# 0      0    India             No  66777.0  23.0
# 1      1   Russia            Yes  87878.0  24.0
# 2      2  Germany             No  34559.0   NaN
# 3      3    India            Yes  40000.0  26.0
# 4      4  Germany            Yes      NaN  21.0
# 5      5   Russia             No  45000.0   NaN
# 6      6  Germany            Yes  89993.0  62.0
# 7      7    India             No  55555.0  24.0
# 8      8   Russia            Yes      NaN  45.0
# 9      9  Germany            Yes  67222.0  53.0

# %%
df1=pd.DataFrame(data=ds)

# %%
le=LabelEncoder()
#df['City']=le.fit_transform(df['City'])

list2=['Nation','purchased_item']
for val in list2:
    df1[val]=le.fit_transform(df1[val].astype(str))  #astype(str) is given to treat the column value as string by force
    
df1
# Out:
#    index  Nation  purchased_item   salary   age
# 0      0       1               0  66777.0  23.0
# 1      1       2               1  87878.0  24.0
# 2      2       0               0  34559.0   NaN
# 3      3       1               1  40000.0  26.0
# 4      4       0               1      NaN  21.0
# 5      5       2               0  45000.0   NaN
# 6      6       0               1  89993.0  62.0
# 7      7       1               0  55555.0  24.0
# 8      8       2               1      NaN  45.0
# 9      9       0               1  67222.0  53.0

# %%
ds=pd.read_csv('age_salary.csv')
ds
# Out:
#    index   Nation purchased_item   salary   age
# 0      0    India             No  66777.0  23.0
# 1      1   Russia            Yes  87878.0  24.0
# 2      2  Germany             No  34559.0   NaN
# 3      3    India            Yes  40000.0  26.0
# 4      4  Germany            Yes      NaN  21.0
# 5      5   Russia             No  45000.0   NaN
# 6      6  Germany            Yes  89993.0  62.0
# 7      7    India             No  55555.0  24.0
# 8      8   Russia            Yes      NaN  45.0
# 9      9  Germany            Yes  67222.0  53.0

# %%
df2=pd.DataFrame(data=ds)
df2
# Out:
#    index   Nation purchased_item   salary   age
# 0      0    India             No  66777.0  23.0
# 1      1   Russia            Yes  87878.0  24.0
# 2      2  Germany             No  34559.0   NaN
# 3      3    India            Yes  40000.0  26.0
# 4      4  Germany            Yes      NaN  21.0
# 5      5   Russia             No  45000.0   NaN
# 6      6  Germany            Yes  89993.0  62.0
# 7      7    India             No  55555.0  24.0
# 8      8   Russia            Yes      NaN  45.0
# 9      9  Germany            Yes  67222.0  53.0

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()

# %%
#X = [['Yes', 1], ['No', 0]]

df2['purchased_item']=ohe.fit_transform(df2['purchased_item'].values.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17048/3664290175.py in <module>
#       1 #X = [['Yes', 1], ['No', 0]]
#       2
# ----> 3 df2['purchased_item']=ohe.fit_transform(df2['purchased_item'].values.reshape(-1,1))
#       4
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
# ...

# %%
import pandas as pd

ids = [11, 22, 33, 44, 55, 66, 77]
countries = ['Spain', 'France', 'Spain', 'Germany', 'France']

df = pd.DataFrame(list(zip(ids, countries)),
                  columns=['Ids', 'Countries'])

df

# %%
x=ds.iloc[:,[0,1,3,4]]
x

# %%
y=ds.iloc[:,2].values
y

# %%
y.shape

# %%
y=y.reshape(-1,1)
y

# %%
y.shape

# %%
one=LabelEncoder()
y=one.fit_transform(y)

# %%
y

# %%
df_dummies=pd.get_dummies(df.City)
df_dummies

# %%
ds=pd.read_csv('abalone.csv')
ds

# %%
df=pd.DataFrame(data=ds)
df

# %%
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'].astype(str))  #astype(str) is given to treat the column value as string by force
    
df

# %%
df

# %%
ds=pd.read_csv('abalone.csv')

df=pd.DataFrame(data=ds)
df

# %%
df_dummies=pd.get_dummies(df.Sex)
df_dummies

# %%
ds=pd.read_csv('Concrete_Data.csv')

df=pd.DataFrame(data=ds)
df

# %%
ds=pd.read_excel('E:\DATA_TRAINED\myfiles\LEARNING/Concrete_Data.xls')
ds

# %%
df=pd.DataFrame(data=ds)
df

# %%
ds=pd.read_csv('Concrete_Data.csv')

data=pd.DataFrame(data=ds)
data

# %%
data.shape

# %%
data.dtypes

# %%
data.info

# %%
data.describe()

# %%
data.columns

# %%
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

# %%
x.shape

# %%
y.shape

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)

# %%
pred=lm.predict(x_test)

# %%
print("predicted and actual values are =",pred,y_test)

# %%
lm.coef_

# %%
lm.intercept_

# %%
lm.score(x_train,y_train)

# %%
print("Error :")

print("Mean Absolute Error = ",mean_absolute_error(y_test,pred))
print("mean squared error = ",mean_squared_error(y_test,pred))

print("root mean squared error = ",np.sqrt(mean_squared_error(y_test,pred)))
